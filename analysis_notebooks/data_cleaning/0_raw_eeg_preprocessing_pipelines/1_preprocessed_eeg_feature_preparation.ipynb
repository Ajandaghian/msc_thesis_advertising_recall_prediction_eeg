# %% [markdown]
# # Import libraries

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Import preprocessed data

# %%
# config settings
path_input = r"../../../data/processed/eeg/preprocessed/"
os.makedirs(path_input, exist_ok=True)

path_output = r"../../../data/processed/eeg/"
os.makedirs(path_output, exist_ok=True)

input_meta_path = r"../../../data/other/tables/table_metadata-studies.csv"


unaided_recall_path = r"../../../data/other/tables/table_unaided-recall.csv"
aided_recall_path = r"../../../data/other/tables/table_aided-recall.csv"

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Drop subjects with invalid channels

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Drop subjects with technical issues

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Create variables 'stimuli_type' and 'stimuli_type_order'

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Create study metadata variables

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## Drop 'gender' == 'Altro/preferisco non rispondere'

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Create unaided recall variable

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Create aided recall variables

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Initialize 'metrics' dictionary

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## 'metrics' dict: assign mean PSD single-electrode variables

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Aggregate mean PSD by montage

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## 'metrics' dict: assign PSD montage variables

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## Visualize mean Power Spectral Density

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## Drop participants after visual inspection

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Calculate GFP

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## 'metrics' dict: assign GFP variables

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Calculate attention & engagement indices

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## 'metrics' dict: assign EI and AI variables

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Calculate Frontal Alpha Asymmetry

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## 'metrics' dict: assign FAA variables

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Normalize variables

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## Z-score on program baseline

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# ### 'metrics' dict: assign zscore (program) variables

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## Z-score on entire stimuli

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# ### 'metrics' dict: assign zscore (all) variables

# %%
< RemovedDueToNDA >

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## log + z-score on program baseline

# %%
< RemovedDueToNDA >

# %% [markdown]
# ## log + z-score on entire stimuli

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Normality check

# %%
< RemovedDueToNDA >

# %% [markdown]
# # Excel export

# %%
df_eeg.shape

#(201322, 2140)

# %%
#write metrics to a text file
with open(os.path.join(path_output, "metrics.txt"), "w") as f:
    import pprint
    pprint.pprint(metrics, stream=f)

# %%
df_eeg.head()

# %%
# --- base path and timestamp ---
out_dir = path_output

# --- build full path with timestamp ---
out_path_csv = os.path.join(out_dir, f"df_eeg_sample.csv")
out_path_parquet = os.path.join(out_dir, f"df_eeg.parquet")


# --- export ---
if not os.path.exists(out_dir):
    os.makedirs(out_dir)

df_eeg.head(50).to_csv(out_path_csv, index=False)

# Save parquet to preserve data types and save space
df_eeg.to_parquet(out_path_parquet, index=False, compression='snappy')


print(f"File saved to: {out_path_parquet}")

# %%
# --- save ---
with open(path_output+"metrics.pkl", "wb") as f:
    pickle.dump(metrics, f)

# %% [markdown]
# ---
